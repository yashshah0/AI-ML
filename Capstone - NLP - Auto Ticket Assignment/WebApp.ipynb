# %%
# !pip install jupyter-dash

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import os
os.chdir('/content/drive/My Drive/Colab Notebooks')

# %%
from jupyter_dash import JupyterDash
import dash
from dash.dependencies import Input, Output, State
import dash_core_components as dcc
import dash_html_components as html
from dash import no_update
import requests
import json

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']
app = JupyterDash(__name__, external_stylesheets=external_stylesheets)
app.layout = html.Div([
    html.H1(children="IT Ticket Auto Assignment", style={'textAlign': 'center'}),
    dcc.Markdown('''
                ###### Step 1: Enter the Short Description and Description of the query you have.
                ###### Step 2: Click submit
                ###### Step 3: Wait for your assigned group to appear! The team will approah you shortly! 
    ''',style={'textAlign': 'center'}),
    
    dcc.Input(id='Short description',type='text'),
    dcc.Input(id='Description',type='text'),
    html.Button(id='submit-button', type='submit', children='Submit'),
    html.Div(id='output_div')
    ],style={'textAlign': 'center','justify':'center','align':'middle','verticalAlign':'middle'})

@app.callback(Output('output_div', 'children'),
                [Input(component_id='submit-button',component_property= 'n_clicks'),
                 Input(component_id='Short description',component_property= 'value'),
                 Input(component_id='Description',component_property= 'value')],
               # [State('Description', 'value')],
                )

def update_output(clicks, input_value_1,input_value):
  data=json.dumps({'Short description':input_value_1,'Description':input_value})
  #Always update the tunneling server link after running the server code.
  r=requests.post("http://c2166471e9bd.ngrok.io",data)
  string = r.json()[0]
  string = string.replace('_',' ')
  if clicks is not None:
        if input_value is not None:
          return(html.H2(children=("Your case has been assigned to: ",string[9:]), style={'textAlign': 'center'}))

# %%
app.run_server(mode='external')
# Out:
# Dash app running on:

# %%
#Test Run
import requests
import json

data=json.dumps({'Short description':' windows password','Description':'vip windows password reset for tifpdchb pedxruyf'})
r=requests.post("http://c333d6b599f9.ngrok.io",data)
string = r.json()[0]
string = string.replace('_',' ')
print("Your case has been assigned to ",string[9:])
# Out:
# Your case has been assigned to  GRP 0
